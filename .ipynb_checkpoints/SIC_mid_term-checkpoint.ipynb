# %%
##PREDICTION GPA USE Linear Regression model

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
df = pd.read_csv('Student_performance_data _.csv')
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# min           0.001057     0.000000     0.000000         0.000000
# 25%           5.043079     7.000000     0.000000         1.000000
# 50%           9.705363    15.000000     0.000000         2.000000
# 75%          14.408410    22.000000     1.000000         3.000000
# max          19.978094    29.000000     1.000000         4.000000
#
#        Extracurricular       Sports        Music  Volunteering          GPA  \
# count      2392.000000  2392.000000  2392.000000   2392.000000  2392.000000
# mean          0.383361     0.303512     0.196906      0.157191     1.906186
# std           0.486307     0.459870     0.397744      0.364057     0.915156
# min           0.000000     0.000000     0.000000      0.000000     0.000000
# 25%           0.000000     0.000000     0.000000      0.000000     1.174803
# 50%           0.000000     0.000000     0.000000      0.000000     1.893393
# 75%           1.000000     1.000000     0.000000      0.000000     2.622216
# max           1.000000     1.000000     1.000000      1.000000     4.000000
#
#         GradeClass
# count  2392.000000
# mean      2.983696
# std       1.233908
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000

# %%
print(df.isnull().sum())
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.nunique()
# Out:
# StudentID            2392
# Age                     4
# Gender                  2
# Ethnicity               4
# ParentalEducation       5
# StudyTimeWeekly      2392
# Absences               30
# Tutoring                2
# ParentalSupport         5
# Extracurricular         2
# Sports                  2
# Music                   2
# Volunteering            2
# GPA                  2371
# GradeClass              5
# dtype: int64

# %%
#vẽ biểu đồ bar
countplots = df.drop(columns=['Absences', 'StudyTimeWeekly','GPA','StudentID'])
columns = countplots.columns

fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
axs = ax.flatten()

for i, column in enumerate(columns):
    sns.countplot(x=column, data=df, ax=axs[i], palette='flare')
    axs[i].set_title(f'Count Plot for {column}')
    axs[i].set_xlabel(column)
    axs[i].set_ylabel('Count')

for j in range(i + 1, len(axs)):
    fig.delaxes(axs[j])

plt.tight_layout()
plt.show()

# %%
df.loc[:,'GPA'].plot.hist(bins=30,color='orange',alpha=0.2,title='GPA')

plt.show()

# %%
df.loc[:,'StudyTimeWeekly'].plot.hist(bins=30,color='orange',alpha=0.2,title='StudyTimeWeekly')

plt.show()

# %%
#Tính hệ số tương quan các thuộc tính
corr_matrix = df.corr()
corr_matrix
# Out:
#                    StudentID       Age    Gender  Ethnicity  \
# StudentID           1.000000 -0.042255 -0.014625  -0.012990
# Age                -0.042255  1.000000  0.044895  -0.028473
# Gender             -0.014625  0.044895  1.000000   0.016010
# Ethnicity          -0.012990 -0.028473  0.016010   1.000000
# ParentalEducation  -0.002307  0.025099  0.006771   0.033595
# StudyTimeWeekly     0.026976 -0.006800  0.011469   0.007184
# Absences            0.014841 -0.011511  0.021479  -0.025712
# Tutoring           -0.007834 -0.012076 -0.031597  -0.017440
# ParentalSupport     0.003016  0.033197  0.008065   0.020922
# Extracurricular    -0.003611 -0.025061 -0.005964  -0.008927
# Sports             -0.020703 -0.046320 -0.008897  -0.004484
# Music              -0.005468 -0.003492  0.007109  -0.014627
# Volunteering        0.008011  0.013074 -0.000200   0.013468
# GPA                -0.002697  0.000275 -0.013360   0.027760
# GradeClass         -0.098500 -0.006250  0.022998  -0.023326
#
#                    ParentalEducation  StudyTimeWeekly  Absences  Tutoring  \
# StudentID                  -0.002307         0.026976  0.014841 -0.007834
# Age                         0.025099        -0.006800 -0.011511 -0.012076
# Gender                      0.006771         0.011469  0.021479 -0.031597
# Ethnicity                   0.033595         0.007184 -0.025712 -0.017440
# ParentalEducation           1.000000        -0.011051  0.036518 -0.017340
# StudyTimeWeekly            -0.011051         1.000000  0.009326  0.028930
# Absences                    0.036518         0.009326  1.000000 -0.015534
# Tutoring                   -0.017340         0.028930 -0.015534  1.000000
# ParentalSupport            -0.017463         0.035800  0.002108 -0.000824
# Extracurricular             0.007479        -0.022860  0.000360  0.004865
# Sports                      0.002029         0.006836  0.041454  0.006278
# Music                       0.039439         0.007791 -0.008692 -0.011385
# Volunteering                0.011960        -0.016604 -0.018528 -0.050898
# GPA                        -0.035854         0.179275 -0.919314  0.145119
# GradeClass                  0.041031        -0.134131  0.728633 -0.111695
#
#                    ParentalSupport  Extracurricular    Sports     Music  \
# StudentID                 0.003016        -0.003611 -0.020703 -0.005468
# Age                       0.033197        -0.025061 -0.046320 -0.003492
# Gender                    0.008065        -0.005964 -0.008897  0.007109
# Ethnicity                 0.020922        -0.008927 -0.004484 -0.014627
# ParentalEducation        -0.017463         0.007479  0.002029  0.039439
# StudyTimeWeekly           0.035800        -0.022860  0.006836  0.007791
# Absences                  0.002108         0.000360  0.041454 -0.008692
# Tutoring                 -0.000824         0.004865  0.006278 -0.011385
# ParentalSupport           1.000000        -0.008381 -0.006176  0.035122
# Extracurricular          -0.008381         1.000000 -0.011820 -0.014191
# Sports                   -0.006176        -0.011820  1.000000 -0.020474
# Music                     0.035122        -0.014191 -0.020474  1.000000
# Volunteering             -0.006036        -0.007427 -0.002799  0.017224
# GPA                       0.190774         0.094078  0.057859  0.073318
# GradeClass               -0.136823        -0.069733 -0.026654 -0.036065
#
#                    Volunteering       GPA  GradeClass
# StudentID              0.008011 -0.002697   -0.098500
# Age                    0.013074  0.000275   -0.006250
# Gender                -0.000200 -0.013360    0.022998
# Ethnicity              0.013468  0.027760   -0.023326
# ParentalEducation      0.011960 -0.035854    0.041031
# StudyTimeWeekly       -0.016604  0.179275   -0.134131
# Absences              -0.018528 -0.919314    0.728633
# Tutoring              -0.050898  0.145119   -0.111695
# ParentalSupport       -0.006036  0.190774   -0.136823
# Extracurricular       -0.007427  0.094078   -0.069733
# Sports                -0.002799  0.057859   -0.026654
# Music                  0.017224  0.073318   -0.036065
# Volunteering           1.000000  0.003258    0.013156
# GPA                    0.003258  1.000000   -0.782835
# GradeClass             0.013156 -0.782835    1.000000

# %%
#biểu đồ heatmap
plt.figure(figsize=(14, 14))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".3f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Vẽ biểu đồ scatter
for column in df.columns:
    if column != 'GPA':
        plt.scatter(df['GPA'], df[column], label=column)
        
        plt.title(f'Scatter Plot of GPA vs {column}')
        plt.xlabel('GPA')
        plt.ylabel(f'Values of {column}')
        plt.legend()
        plt.show()

# %%
df.head()
# Out:
#    Age  Gender  ParentalEducation  StudyTimeWeekly  Absences  Tutoring  \
# 0   17       1                  2        19.833723         7         1
# 1   18       0                  1        15.408756         0         0
# 2   15       0                  3         4.210570        26         0
# 3   17       1                  3        10.028829        14         0
# 4   17       1                  2         4.672495        17         1
#
#    ParentalSupport  Extracurricular  Sports  Music  Volunteering  GradeClass
# 0                2                0       0      1             0         2.0
# 1                1                0       0      0             0         1.0
# 2                2                0       0      0             0         4.0
# 3                3                1       0      0             0         3.0
# 4                3                0       0      0             0         4.0

# %%
#Chia tệp huấn luyện(bỏ StudentID, Ethnicity(vì không liên quan đến GPA),bỏ GradeClass vì GPA quyết định GradeClass  )
x = df.drop(columns= ['StudentID', 'Ethnicity', 'GPA','GradeClass'])
y = df['GPA']

from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
# Initialize the Linear Regression model
linreg = LinearRegression()

# Fit the model to the training data
linreg.fit(x_train, y_train)

# Predict the target variable for the test set
y_pred_lreg = linreg.predict(x_test)
print(y_pred_lreg)
# Out:
# [ 3.249739    2.76463941  1.62912935  2.09755856  1.64234504  2.50777119
#   3.32892365  2.23501713  1.04387744  2.140896    1.01933008  2.21878736
#   2.65994103  2.45980777  2.01821203  3.56462265  1.64668741  2.07583255
#   2.81505463  3.0299892   1.07458317  1.3254424   2.7979476   0.98470839
#   2.59667361  1.02100338  2.24919829  1.77915669  1.30556343  3.24165679
#   2.38000177  3.14919179  2.97392005  2.4022506   2.15338888  3.36622308
#   0.48974253  2.77524855  1.71061391  0.56153981  1.15645357  0.74852182
#   3.13395947  1.25222258  2.88354929  3.20901818  3.18749722  3.42302321
#   2.85955637  1.56023706  1.02102392 -0.06607222  3.06475826  2.4894148
#   2.46510883  2.80155725  1.08167747  3.01975134  3.22727174  1.29175415
#   1.48951264  2.5421227   2.69267343  3.03827345  3.26274681  3.22229264
#   3.66797781  1.07174691  1.47708732  1.53173182  3.12484626  2.07977207
#   2.10027917  2.25373071  1.47129788  2.61801989  0.7639355   0.68844977
#   2.55809998  0.75963424  0.87140489  1.4591279   1.92524927  3.30307754
#   2.92379827  1.53212565  2.41478608  2.02247546  2.54054645  0.60626742
#   0.93759016  2.00249059  3.35227825  1.08928601  1.54876908  1.48320043
#   1.85600907  1.04733538  0.90053172  1.68882506  0.85600174  2.07826003
#   3.49148236  1.44867146  2.02797167  0.73030434  1.33253371  0.40849735
#   3.30034463  0.81155337  2.84419555  2.51032442  2.01986413  1.67024604
#   1.50321074  2.04657291  0.38148536  1.97495192  3.46494872  0.88700421
#   2.34493432  1.20610445  1.27060526  2.02458139  3.31000162  0.48222337
#   0.68585709  1.16196233  1.68482963  2.43708433  1.7806807   0.77744144
#   2.97102789  2.40263238  1.34841829  0.9635097   3.00705871  3.12943881
#   0.59928275  0.88967277  2.41306156  2.51795465  1.74306225  2.08714306
#   2.48149542  1.53880045 -0.3335654   2.52576476  1.29491943  0.90746365
#   1.48803297  1.68496821  1.03501287  0.82215312  2.58314928  0.32044524
#   1.19268098  3.66544291  0.27195628  2.20296514  1.58341002  1.62164534
#   2.18870811  0.74980276  0.51354256  2.25489112  1.02366963  1.74316081
#   1.8888277   2.61235168  0.20410958  1.34390486  0.99541147  3.23073102
#   1.42028716  0.88053489  2.29230204  3.53678292  1.5074504   0.80719183
#   2.77610759  3.20315638  1.97807962  1.68594555  2.01408654  1.73644967
#   1.58888442  1.02174881  2.52393007  0.27296438  1.24117104  1.39957541
#   1.76653434  2.00934168  0.41927401  1.91182551  3.67985743  3.22545161
#   1.86416811  1.72393355  3.2214488   3.00746013  2.21280002  1.10115903
#   1.16917683  0.18148709  1.77683675  0.9567233   0.94448006  2.7173792
#   2.09508981  1.32889004  2.4384361   2.50987585  2.92542881  0.40070383
#   2.05906494  2.74178741  2.48719234  2.5754299   2.78091774  0.43529748
#   2.31562033  1.40708242  0.80566915  2.51269256  2.63419384  1.90702207
#   2.19728869  2.03665753  2.29455359  2.50041664  2.58932829  2.17543445
#   1.54931644  2.90304775  2.91961741  2.59646235  0.54307946  1.07441526]

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Calculate the Mean Squared Error
mse = mean_squared_error(y_test, y_pred_lreg)
print('Mean Squared Error:', mse)

# Calculate the R-squared value
r2 = r2_score(y_test, y_pred_lreg)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 0.03897224208858529
# R-squared: 0.9540115569878636
